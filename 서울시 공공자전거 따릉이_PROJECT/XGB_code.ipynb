# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost
import math
from __future__ import division
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from sklearn import cross_validation, tree, linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score
from sklearn.metrics import accuracy_score
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
data = pd.read_csv('C:\\Users\\admin\\Desktop\\tidyed_final.csv')

# %%
pds = data[data.iloc[:,5] == 1] #set period
pds = pds.drop(['station_num','month','day','hour','minute','period'],axis=1)
pds
# Out:
#        stock  rests_num  lent_count  return_count  empty  total_air_status  \
# 0          0         10           0             0   True                56
# 4          1         10           1             0   True                69
# 8          4         10           0             0  False                49
# 12         5         10           2             3  False                75
# 16         8         10           0             0  False                59
# 20         4         10           1             0  False                65
# 24        15         10           2             0  False                91
# 28         7         10           3             1  False                79
# 32         4         10           0             0  False                87
# 36         6         10           3             2  False                87
# 40         2         10           1             1  False                63
# 44        10         10           4             2  False                75
# 48         4         10           0             0  False                73
# 52         1         10           0             2  False                72
# 56         1         10           0             0  False                71
# 60         8         10           0             1  False                56
# 64         1         10           2             1   True                69
# 68         4         10           0             0  False                49
# 72         5         10           1             1  False                75
# 76         8         10           7             3  False                59
# 80         5         10           2             2  False                65
# 84         5         10           2             1  False                91
# 88        13         10           4             1  False                79
# 92         5         10           3             0  False                87
# 96         4         10           2             2  False                87
# 100        4         10           1             0  False                63
# 104        4         10           1             2  False                75
# 108        3         10           2             2  False                73
# 112        5         10           0             2  False                72
# 116        6         10           0             0  False                71
# ...      ...        ...         ...           ...    ...               ...
# 24880      7         12           7             3  False                58
# 24884      3         12           3             0   True                64
# 24888      3         12           5             2   True                57
# 24892      9         12           4             0  False                66
# 24896      6         12           3             0  False                98
# 24900      3         12           3             2  False                59
# 24904      6         12           6             0   True                74
# 24908      0         12           1             2   True                83
# 24912      6         12           8             2   True                80
# 24916      9         12           3             0  False                80
# 24920      2         12           2             1  False                66
# 24924      8         12           6             3  False                59
# 24928      4         12           1             0  False                56
# 24932      7         13           1             0  False                70
# 24936      6         13           1             1  False                74
# 24940      5         13           0             0  False                49
# 24944      4         13           1             2  False                58
# 24948     12         13           4             1  False                58
# 24952      7         13           3             0  False                64
# 24956      6         13           3             0  False                57
# 24960      5         13           0             0  False                66
# 24964      9         13           0             1  False                98
# 24968      6         13           2             0  False                59
# 24972      6         13           3             1  False                74
# 24976     19         13           3             0  False                83
# 24980      1         13           1             1  False                80
# 24984      8         13           1             0  False                80
# 24988      6         13           1             0  False                66
# 24992      7         13           0             0  False                59
# 24996      8         13           0             1  False                56
#
#        PM10_level  avg_temp  avg_humi  wind_speed   ...    avg_bikestn_dis  \
# 0              44      25.3      89.7    0.788457   ...        3424.356902
# 4              58      28.0      73.7    0.741937   ...        3424.356902
# 8              37      27.0      88.8    0.530628   ...        3424.356902
# 12             65      28.3      77.5    0.262364   ...        3424.356902
# 16             34      27.4      72.0    0.405465   ...        3424.356902
# 20             54      30.2      69.6    0.470004   ...        3424.356902
# 24             62      30.0      69.3    0.530628   ...        3424.356902
# 28             72      32.6      66.1    0.788457   ...        3424.356902
# 24952       0.510690        0.242454   1851.60656       0.064869       0
# 24956       0.510690        0.242454   1851.60656       0.064869       0
# 24960       0.510690        0.242454   1851.60656       0.064869       0
# 24964       0.510690        0.242454   1851.60656       0.064869       0
# 24968       0.510690        0.242454   1851.60656       0.064869       0
# 24972       0.510690        0.242454   1851.60656       0.064869       0
# 24976       0.510690        0.242454   1851.60656       0.064869       0
# 24980       0.510690        0.242454   1851.60656       0.064869       0
# 24984       0.510690        0.242454   1851.60656       0.064869       0
# 24988       0.510690        0.242454   1851.60656       0.064869       0
# 24992       0.510690        0.242454   1851.60656       0.064869       0
# 24996       0.510690        0.242454   1851.60656       0.064869       0
#
# [6250 rows x 74 columns]

# %%
X = pds.iloc[:,5:]
y = pds['return_count'] #return_count or lent_count

# %% [markdown]
# #### correlation

# %%
features = X.columns.tolist() #variable name list
target = y.name

# %%
correlations = {}
for f in features:
    data_temp = data[[f,target]]
    x1 = data_temp[f].values
    x2 = data_temp[target].values
    key = f + ' vs ' + target
    correlations[key] = pearsonr(x1,x2)[0]

# %%
#correlations with return_count(y)
data_correlations = pd.DataFrame(correlations, index=['Value']).T
data_correlations.loc[data_correlations['Value'].abs().sort_values(ascending=False).index]
# Out:
#                                             Value
# avg_alt vs return_count                 -0.327694
# nrt_sub_dis vs return_count             -0.219243
# compop vs return_count                   0.179392
# flo_10 vs return_count                   0.176631
# flo_30 vs return_count                   0.172994
# avg_humi vs return_count                -0.171026
# flo_40 vs return_count                   0.170556
# flo_50 vs return_count                   0.160050
# avg_bikestn_dis vs return_count         -0.158829
# flo_20 vs return_count                   0.157842
# flo_60 vs return_count                   0.153138
# bikeroad_len vs return_count             0.149605
# busstn_count vs return_count             0.146656
# com1030_ratio vs return_count            0.144907
# livpop_m_1014 vs return_count           -0.143481
# livpop_m_509 vs return_count            -0.143246
# livpop_w_509 vs return_count            -0.143043
# road_link_count_in_dong vs return_count  0.137059
# livpop_w_1014 vs return_count           -0.135537
# cumu_rain vs return_count               -0.133677
# flo1030_ratio vs return_count            0.133584
# livpop_w_I00 vs return_count            -0.125574
# livpop_m_4 vs return_count              -0.121182
# livpop_w_1519 vs return_count           -0.113178
# livpop_m_1519 vs return_count           -0.105700
# livpop_w_4 vs return_count              -0.102267
# livpop_m_4549 vs return_count           -0.101508
# livpop_w_4044 vs return_count           -0.095620
# livpop_w_9094 vs return_count           -0.093674
# livpop_m_4044 vs return_count           -0.091473
# ...                                           ...
# total_air_status vs return_count         0.074110
# livpop_m_2024 vs return_count           -0.073891
# wind_speed vs return_count              -0.073199
# livpop_m_8084 vs return_count           -0.067410
# livpop_m_6569 vs return_count           -0.065540
# livpop_w_8589 vs return_count           -0.065445
# livpop_w_6064 vs return_count           -0.064952
# livpop_w_2024 vs return_count           -0.063319
# livpop_m_9094 vs return_count           -0.062584
# livpop_m_7074 vs return_count           -0.061203
# livpop_m_7579 vs return_count           -0.059399
# livpop_w_7579 vs return_count           -0.058864
# sd_bikestn_dis vs return_count           0.058148
# livpop_w_8084 vs return_count           -0.057409
# livpop_w_9599 vs return_count           -0.056995
# PM10_level vs return_count               0.053853
# livpop_m_9599 vs return_count           -0.050802
# livpop_w_6569 vs return_count           -0.045540
# livpop_w_3539 vs return_count           -0.042837
# livpop_w_7074 vs return_count           -0.040201
# live1030_ratio vs return_count          -0.040117
# livpop_m_8589 vs return_count           -0.036685
# livpop_m_I00 vs return_count            -0.034226
# kosdaq vs return_count                   0.029795
# nrt_bikestn_dis vs return_count         -0.027596
# livpop_w_2529 vs return_count            0.021226
# bikestn_count vs return_count            0.018025
# livpop_m_3539 vs return_count           -0.007199
# nrt_busstn_dis vs return_count           0.003516
# livpop_m_2529 vs return_count           -0.000877
#
# [69 rows x 1 columns]

# %% [markdown]
# #### XGBoost

# %%
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y ,test_size=0.2)

# %%
# Let's try XGboost algorithm to see if we can get better results
xgb = xgboost.XGBRegressor(n_estimators=1000, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=7,seed=1)

# %%
xgb.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.08, max_delta_step=0,
#        max_depth=7, min_child_weight=1, missing=None, n_estimators=1000,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=1, silent=True,
#        subsample=0.75)

# %%
predictions = xgb.predict(X_test)
print(explained_variance_score(predictions,y_test))
# Out:
# 0.2654893376604379

# %%
from sklearn.metrics import mean_squared_error
import math
testScore=math.sqrt(mean_squared_error(y_test,predictions))
print(testScore)
# Out:
# 1.4066706073728092

# %% [markdown]
# ##### feature importance

# %%
importance = xgb.feature_importances_

# %%
import_lst = importance.tolist()

# %%
dictionary = dict(zip(features,import_lst))
dictionary
# Out:
# {'total_air_status': 0.14416304230690002,
#  'PM10_level': 0.085938960313797,
#  'avg_temp': 0.10260112583637238,
#  'avg_humi': 0.09842519462108612,
#  'wind_speed': 0.0672927126288414,
#  'cumu_rain': 0.019726591184735298,
#  'road_link_count_in_dong': 0.0204329676926136,
#  'flo_10': 0.01591423712670803,
#  'flo_20': 0.008684271015226841,
#  'flo_30': 0.004300583619624376,
#  'flo_40': 0.0025346435140818357,
#  'flo_50': 0.0028047284577041864,
#  'flo_60': 0.003708474338054657,
#  'livpop_m_1014': 0.00887125264853239,
#  'livpop_m_1519': 0.005256269127130508,
#  'livpop_m_2024': 0.0060769119299948215,
#  'livpop_m_2529': 0.0061288513243198395,
#  'livpop_m_3034': 0.0050069596618413925,
#  'livpop_m_3539': 0.00392661988735199,
#  'livpop_m_4': 0.004622607957571745,
#  'livpop_m_4044': 0.0019217584049329162,
#  'livpop_m_4549': 0.0014646915951743722,
#  'livpop_m_5054': 0.001973697915673256,
#  'livpop_m_509': 0.0021814554929733276,
#  'livpop_m_5559': 0.0017971039051190019,
#  'livpop_m_6064': 0.0014335279120132327,
#  'livpop_m_6569': 0.001963309943675995,
#  'livpop_m_7074': 0.0017451643943786621,
#  'livpop_m_7579': 0.0016620613168925047,
#  'livpop_m_8084': 0.002316497964784503,
#  'livpop_m_8589': 0.003189080161973834,
#  'livpop_m_9094': 0.0036253712605684996,
#  'livpop_m_9599': 0.0035214924719184637,
#  'livpop_m_I00': 0.0015166309894993901,
#  'livpop_w_1014': 0.001973697915673256,
#  'livpop_w_1519': 0.0015893462114036083,
#  'livpop_w_2024': 0.0025969708804041147,
#  'livpop_w_2529': 0.002337273908779025,
#  'livpop_w_3034': 0.0028151164297014475,
#  'livpop_w_3539': 0.0011738308239728212,
#  'livpop_w_4': 0.001391976373270154,
#  'livpop_w_4044': 0.0008102549472823739,
#  'livpop_w_4549': 0.0004986184067092836,
#  'livpop_w_5054': 0.0005609457148239017,
#  'livpop_w_509': 0.0006440487923100591,
#  'livpop_w_5559': 0.00047784263733774424,
#  'livpop_w_6064': 0.0016412856057286263,
#  'livpop_w_6569': 0.0009349095053039491,
#  'livpop_w_7074': 0.0007583154947496951,
#  'livpop_w_7579': 0.0009556852746754885,
#  'livpop_w_8084': 0.0013088732957839966,
#  'livpop_w_8589': 0.0017659402219578624,
#  'livpop_w_9094': 0.002015249338001013,
#  'livpop_w_9599': 0.0036876986268907785,
#  'livpop_w_I00': 0.0025969708804041147,
#  'avg_alt': 0.06932873278856277,
#  'bikeroad_len': 0.03844555839896202,
#  'bikestn_count': 0.01279787253588438,
#  'busstn_count': 0.025658072903752327,
#  'avg_bikestn_dis': 0.022385889664292336,
#  'sd_bikestn_dis': 0.018531983718276024,
#  'nrt_bikestn_dis': 0.01924874819815159,
#  'nrt_busstn_dis': 0.032534852623939514,
#  'nrt_sub_dis': 0.025543805211782455,
#  'flo1030_ratio': 0.0062015666626393795,
#  'live1030_ratio': 0.004913468845188618,
#  'compop': 0.021430203691124916,
#  'com1030_ratio': 0.020297924056649208,
#  'kosdaq': 0.003417613683268428}

# %%
import operator
sorted_x = sorted(dictionary.items(), key=operator.itemgetter(1))
sorted_x #feature_importances_sorted
# Out:
# [('livpop_w_5559', 0.00047784263733774424),
#  ('livpop_w_4549', 0.0004986184067092836),
#  ('livpop_w_5054', 0.0005609457148239017),
#  ('livpop_w_509', 0.0006440487923100591),
#  ('livpop_w_7074', 0.0007583154947496951),
#  ('livpop_w_4044', 0.0008102549472823739),
#  ('livpop_w_6569', 0.0009349095053039491),
#  ('livpop_w_7579', 0.0009556852746754885),
#  ('livpop_w_3539', 0.0011738308239728212),
#  ('livpop_w_8084', 0.0013088732957839966),
#  ('livpop_w_4', 0.001391976373270154),
#  ('livpop_m_6064', 0.0014335279120132327),
#  ('livpop_m_4549', 0.0014646915951743722),
#  ('livpop_m_I00', 0.0015166309894993901),
#  ('livpop_w_1519', 0.0015893462114036083),
#  ('livpop_w_6064', 0.0016412856057286263),
#  ('livpop_m_7579', 0.0016620613168925047),
#  ('livpop_m_7074', 0.0017451643943786621),
#  ('livpop_w_8589', 0.0017659402219578624),
#  ('livpop_m_5559', 0.0017971039051190019),
#  ('livpop_m_4044', 0.0019217584049329162),
#  ('livpop_m_6569', 0.001963309943675995),
#  ('livpop_m_5054', 0.001973697915673256),
#  ('livpop_w_1014', 0.001973697915673256),
#  ('livpop_w_9094', 0.002015249338001013),
#  ('livpop_m_509', 0.0021814554929733276),
#  ('livpop_m_8084', 0.002316497964784503),
#  ('livpop_w_2529', 0.002337273908779025),
#  ('flo_40', 0.0025346435140818357),
#  ('livpop_w_2024', 0.0025969708804041147),
#  ('livpop_w_I00', 0.0025969708804041147),
#  ('flo_50', 0.0028047284577041864),
#  ('livpop_w_3034', 0.0028151164297014475),
#  ('livpop_m_8589', 0.003189080161973834),
#  ('kosdaq', 0.003417613683268428),
#  ('livpop_m_9599', 0.0035214924719184637),
#  ('livpop_m_9094', 0.0036253712605684996),
#  ('livpop_w_9599', 0.0036876986268907785),
#  ('flo_60', 0.003708474338054657),
#  ('livpop_m_3539', 0.00392661988735199),
#  ('flo_30', 0.004300583619624376),
#  ('livpop_m_4', 0.004622607957571745),
#  ('live1030_ratio', 0.004913468845188618),
#  ('livpop_m_3034', 0.0050069596618413925),
#  ('livpop_m_1519', 0.005256269127130508),
#  ('livpop_m_2024', 0.0060769119299948215),
#  ('livpop_m_2529', 0.0061288513243198395),
#  ('flo1030_ratio', 0.0062015666626393795),
#  ('flo_20', 0.008684271015226841),
#  ('livpop_m_1014', 0.00887125264853239),
#  ('bikestn_count', 0.01279787253588438),
#  ('flo_10', 0.01591423712670803),
#  ('sd_bikestn_dis', 0.018531983718276024),
#  ('nrt_bikestn_dis', 0.01924874819815159),
#  ('cumu_rain', 0.019726591184735298),
#  ('com1030_ratio', 0.020297924056649208),
#  ('road_link_count_in_dong', 0.0204329676926136),
#  ('compop', 0.021430203691124916),
#  ('avg_bikestn_dis', 0.022385889664292336),
#  ('nrt_sub_dis', 0.025543805211782455),
#  ('busstn_count', 0.025658072903752327),
#  ('nrt_busstn_dis', 0.032534852623939514),
#  ('bikeroad_len', 0.03844555839896202),
#  ('wind_speed', 0.0672927126288414),
#  ('avg_alt', 0.06932873278856277),
#  ('PM10_level', 0.085938960313797),
#  ('avg_humi', 0.09842519462108612),
#  ('avg_temp', 0.10260112583637238),
#  ('total_air_status', 0.14416304230690002)]

# %%
from matplotlib import pyplot
# plot
pyplot.bar(range(len(xgb.feature_importances_)), xgb.feature_importances_)
pyplot.show()

# %%
from xgboost import plot_importance
# plot feature importance
plot_importance(xgb) #weight
pyplot.show()

# %% [markdown]
# #### feature selection

# %%
from numpy import sort
from sklearn.feature_selection import SelectFromModel
thresholds = sort(xgb.feature_importances_)
for thresh in thresholds:
    # select features using threshold
    selection = SelectFromModel(xgb, threshold=thresh, prefit=True)
    select_X_train = selection.transform(X_train)
    # train model
    selection_model = xgboost.XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=7)
    selection_model.fit(select_X_train, y_train)
    # eval model
    select_X_test = selection.transform(X_test)
    y_pred = selection_model.predict(select_X_test)
    rmse = ((y_pred - y_test)**2).mean()**0.5
    
    #print("Thresh=%.3f, n=%d, rmse: %.2f" % (thresh, select_X_train.shape[1], rmse))

# %%
from sklearn.metrics import r2_score
from numpy import sort
from sklearn.feature_selection import SelectFromModel
thresholds = sort(xgb.feature_importances_)
for thresh in thresholds:
    # select features using threshold
    selection = SelectFromModel(xgb, threshold=thresh, prefit=True)
    select_X_train = selection.transform(X_train)
    # train model
    selection_model = xgboost.XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=7)
    selection_model.fit(select_X_train, y_train)
    # eval model
    select_X_test = selection.transform(X_test)
    y_pred = selection_model.predict(select_X_test)
    
    r_squared = r2_score(y_test,y_pred,multioutput='variance_weighted')
    adjusted_r_squared = 1 - (1-r_squared)*(len(y_pred)-1)/(len(y_pred)-2)
    
    
    #print("Thresh=%.3f, n=%d, a_r2: %.2f" % (thresh, select_X_train.shape[1], adjusted_r_squared))
    print(r_squared,adjusted_r_squared)

# %% [markdown]
# #### CV

# %%
from numpy import sort
from sklearn.feature_selection import SelectFromModel
from sklearn import model_selection
thresholds = sort(xgb.feature_importances_)
for thresh in thresholds:
    # select features using threshold
    selection = SelectFromModel(xgb, threshold=thresh, prefit=True)
    select_X = selection.transform(X)
    # train model
    selection_model = xgboost.XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=7)
    selection_model.fit(select_X, y)
    # eval model
    seed = 7
    kfold = model_selection.KFold(n_splits=10, random_state=seed)
    scoring = 'r2'
    
    results = model_selection.cross_val_score(selection_model, select_X, y, cv=kfold, scoring=scoring)
    print(("R^2: %.3f (%.3f)") % (results.mean(), results.std()))

# %% [markdown]
# #### parameters search

# %%
import pprint
from sklearn.grid_search import GridSearchCV
def xgb_model_select(X_train,y_train):  
    xgb_clf = xgboost.XGBRegressor()
    parameters = {
    'colsample_bytree':[0.4,0.6,0.8],
    'gamma':[0,0.03,0.1,0.3],
    'min_child_weight':[1.5,6,10],
    'learning_rate':[0.1,0.07],
    'max_depth':[3,5],
    'n_estimators':[10000],
    'reg_alpha':[1e-5, 1e-2,  0.75],
    'reg_lambda':[1e-5, 1e-2, 0.45],
    'subsample':[0.6,0.95]  
    } # []안의 값 각각 수정가능(개수제한 없음)
    grid_search = GridSearchCV(estimator=xgb_clf, param_grid=parameters, cv=10, n_jobs=-1)
    print("parameters:")
    pprint.pprint(parameters)
    grid_search.fit(X_train, y_train)
    print("Best score: %0.3f" % grid_search.best_score_) #best score 기준 최적 parameter search
    print("Best parameters set:")
    best_parameters=grid_search.best_estimator_.get_params()
    for param_name in sorted(parameters.keys()):
        print("\t%s: %r" % (param_name, best_parameters[param_name]))
    end_time = datetime.datetime.now()
    print ('Select Done..., Time Cost: %d') % ((end_time - start_time).seconds)

# %% [markdown]
# #### prediction

# %%
xgb.predict(X)
# Out:
# array([ 0.05398014, -0.00555915, -0.11170602, ...,  0.03352678,
#         0.11889243,  0.9797745 ], dtype=float32)
